# %%
import os
import getpass
import pandas as pd
import SVGhandler

# %%
# Reading outline
path2SP = f"/Users/{getpass.getuser()}/OneDrive - World Justice Project/EU Subnational/EU-S Data/reports/eu-thematic-reports"
outline = pd.read_excel(f"{path2SP}/data-viz/inputs/report_outline.xlsx")

charts4reports = (
    outline
    .loc[(outline["thematic_reports"] == True) & (outline["type"] != "Box"), ["chart_id", "type"]]
)
charts4reports = dict(zip(charts4reports["chart_id"], charts4reports["type"]))

# %%
# Loading color schemes
region_colors  = pd.read_excel(f"{path2SP}/data-viz/inputs/region_labels.xlsx")
color_range    = pd.read_excel(f"{path2SP}/data-viz/inputs/color_range.xlsx")

color_scheme = {
    "Map"               : region_colors,
    "Dumbbells"         : region_colors,
    "Bars"              : color_range.copy().loc[color_range["level"] == "national"],
    "QRQ Bars"          : color_range.copy().loc[color_range["level"] == "national"],
    "Dots"              : color_range.copy().loc[color_range["level"] == "national"],
    "Lollipop"          : color_range,
    "Table"             : None,
    "Scatterplot"       : region_colors,
    "Map (Categorical)" : region_colors
}

# %%
# Creating sub-directories if not already created
for report in ["R1", "R2", "R3"]:
    os.makedirs(report, exist_ok = True)

# %%
# Using the SVG handler to add interactivity
for chart, type in charts4reports.items():
    original = SVGhandler.svg(chart, type)
    original.addInteractivity(color_scheme[type])
# Out:
# Adding interactivity to chart R1F1: QRQ Bars
# Adding interactivity to chart R1F2: QRQ Bars
# Adding interactivity to chart R1F3: Map
# Adding interactivity to chart R1F4: Map
# Adding interactivity to chart R1F5: QRQ Bars
# Adding interactivity to chart R1F6: QRQ Bars
# Adding interactivity to chart R1F7: Map
# Adding interactivity to chart R1F90: Map
# Adding interactivity to chart R1F91: Map
# Adding interactivity to chart R1F92: Map
# Adding interactivity to chart R1F93: Map
# Adding interactivity to chart R1F8: QRQ Bars
# Adding interactivity to chart R1F9: Map
# Adding interactivity to chart R1F10: Map
# Adding interactivity to chart R1F11: QRQ Bars
# Adding interactivity to chart R1F12: Map
# Adding interactivity to chart R1F13: Map
# Adding interactivity to chart R1F14: Map
# Adding interactivity to chart R1F15: Map
# Adding interactivity to chart R1F16: Map
# Adding interactivity to chart R1F17: Map
# Adding interactivity to chart R1F18: QRQ Bars
# Adding interactivity to chart R1F19: Bars
# Adding interactivity to chart R1F20: Bars
# Adding interactivity to chart R1F21: Bars
# Adding interactivity to chart R1F22: Bars
# Adding interactivity to chart R1F23: Bars
# Adding interactivity to chart R1F24: QRQ Bars
# Adding interactivity to chart R1F25: Bars
# Adding interactivity to chart R1F26: Bars
# Adding interactivity to chart R1F27: Bars
# Adding interactivity to chart R1F28: QRQ Bars
# Adding interactivity to chart R1F29: QRQ Bars
# Adding interactivity to chart R1F30: QRQ Bars
# Adding interactivity to chart R1F31: Bars
# Adding interactivity to chart R1F32: Bars
# Adding interactivity to chart R1F33: QRQ Bars
# Adding interactivity to chart R1F34: Bars
# Adding interactivity to chart R1F35: Bars
# Adding interactivity to chart R1F36: Bars
# Adding interactivity to chart R1F37: Dumbbells
# Data for the following regions not found: HR02, HR06, DK02, DK03, FI19, FRB, FRC, FRD, FRE, FRF, FRH, FRM, DEE
# Adding interactivity to chart R1F38: Map
# Adding interactivity to chart R1F39: Map
# Adding interactivity to chart R1F40: Map
# Adding interactivity to chart R1F41: Dots
# Data for the following regions not found: IE
# Adding interactivity to chart R1F42: Map
# Adding interactivity to chart R1F43: Map
# Adding interactivity to chart R1F44: Map
# Adding interactivity to chart R1F45: Map
# Adding interactivity to chart R1F48: Map
# Adding interactivity to chart R1F49: Dumbbells
# Data for the following regions not found: HR02, HR06, DK02, DK03, FI19, FRB, FRC, FRD, FRE, FRF, FRH, FRM, DE8, DEE, PL6, PL5, SI03
# Adding interactivity to chart R1F50: Dumbbells
# Data for the following regions not found: HR02, HR06, DK02, DK03, FI19, FRB, FRC, FRD, FRF, FRM, DEE, PL7, PL8, PL5
# Adding interactivity to chart R1F51: Dumbbells
# Data for the following regions not found: HR02, HR06, DK02, DK03, FI19, FRB, FRC, FRD, FRF, FRM, DEE, PL7
# Adding interactivity to chart R1F52: Dumbbells
# Data for the following regions not found: HR02, HR06, DK02, DK03, FI19, FRB, FRC, FRD, FRF, FRM, DEE
# Adding interactivity to chart R1F53: Map
# Adding interactivity to chart R1F54: Map
# Adding interactivity to chart R1F55: Map
# Adding interactivity to chart R1F57: Dumbbells
# Data for the following regions not found: HR02, HR06, DK02, DK03, FI19, FRB, FRC, FRD, FRF, FRH, FRM, DEE
# Adding interactivity to chart R1F58: Map
# Adding interactivity to chart R1F59: Map
# Adding interactivity to chart R1F60: Map
# Adding interactivity to chart R1F61: Map
# Adding interactivity to chart R1F62: Map
# Adding interactivity to chart R1F63: Dumbbells
# Data for the following regions not found: BE3, HR02, HR06, DK02, DK03, DK04, DK05, FI19, FI1C20, FRB, FRC, FRD, FRE, FRF, FRM, DEE, IE04, NL4, PT2, SE3
# Adding interactivity to chart R1F64: Dumbbells
# Data for the following regions not found: HR02, HR06, DK02, DK03, FI19, FRB, FRC, FRD, FRE, FRF, FRH, FRI, FRM, DE8, DEE, PL7, PL8, PL6, SI03
# Adding interactivity to chart R1F65: Dumbbells
# Data for the following regions not found: HR02, HR06, DK02, DK03, FI19, FRB, FRC, FRD, FRF, FRM, DEE
# Adding interactivity to chart R1F66: Map
# Adding interactivity to chart R1F67: Map (Categorical)
# Adding interactivity to chart R1F68: Map (Categorical)
# Adding interactivity to chart R1F69: Map
# Adding interactivity to chart R1F70: Dumbbells
# Data for the following regions not found: BE3, HR02, HR06, DK02, DK03, DK05, FI19, FRB, FRC, FRD, FRE, FRF, FRM, DEE, SE3
# Adding interactivity to chart R1F71: Map
# Adding interactivity to chart R1F72: Map
# Adding interactivity to chart R1F73: Map
# Adding interactivity to chart R1F74: Dumbbells
# Data for the following regions not found: HR02, HR06, DK02, DK03, FI19, FRB, FRC, FRD, FRF, FRM, DEE
# Adding interactivity to chart R1F75: Map
# Adding interactivity to chart R1F76: Dumbbells
# Data for the following regions not found: HR02, HR06, DK02, DK03, FI19, FRB, FRC, FRD, FRF, FRM, DEE, IE04, PT2, SE3
# Adding interactivity to chart R1F77: Map
# Adding interactivity to chart R1F78: Map
# Adding interactivity to chart R1F79: Scatterplot
# Adding interactivity to chart R1F80: Dots
# Data for the following regions not found: IE
# Adding interactivity to chart R1F81: Dumbbells
# Data for the following regions not found: HR02, HR06, DK02, DK03, FI19, FRB, FRC, FRD, FRF, FRM, DEE
# Adding interactivity to chart R1F82: Dots
# Data for the following regions not found: IE
# Adding interactivity to chart R1F83: Dumbbells
# Data for the following regions not found: HR02, HR06, DK02, DK03, FI19, FRB, FRC, FRD, FRE, FRF, FRM, DE8, DEE, PL4, SI03
# Adding interactivity to chart R1F84: Dumbbells
# Data for the following regions not found: HR02, HR06, DK02, DK03, DK05, FI19, FRB, FRC, FRD, FRF, FRM, DE8, DEC, DEE, NL1, NL2, PT2, SI03
# Adding interactivity to chart R1F85: Map
# Adding interactivity to chart R1F86: Map
# Adding interactivity to chart R1F87: Map
# Adding interactivity to chart R1F88: Map
# Adding interactivity to chart R1F89: Map
# Adding interactivity to chart R2F1: Dumbbells
# Data for the following regions not found: HR02, DK02, DK05, FI19, FI1D, FRB, FRC, FRD, FRF, FRM, DEE, PT2, SE3
# Adding interactivity to chart R2F2: Map
# Adding interactivity to chart R2F3: Map
# Adding interactivity to chart R2F4: Dumbbells
# Data for the following regions not found: HR02, CZ0708, DK02, DK05, FI19, FI1D, FRB, FRC, FRD, FRF, FRM, DEE, IE04, PT2, SE3
# Adding interactivity to chart R2F5: Map
# Adding interactivity to chart R2F6: Dumbbells
# Data for the following regions not found: HR02, DK02, DK05, FI19, FI1D, FRB, FRC, FRD, FRF, FRM, DEE, PT2, SE3
# Adding interactivity to chart R2F7: Map
# Adding interactivity to chart R2F8: Map
# Adding interactivity to chart R2F9: Dumbbells
# Data for the following regions not found: HR02, DK02, DK05, FI19, FI1D, FRB, FRC, FRD, FRF, FRM, DEE, PT2, SE3
# Adding interactivity to chart R2F10: Map
# Adding interactivity to chart R2F11: Map
# Adding interactivity to chart R2F12: Map
# Adding interactivity to chart R2F13: Map
# Adding interactivity to chart R2F14: Map
# Adding interactivity to chart R2F15: Dumbbells
# Data for the following regions not found: AT2, BE2, HR02, CZ0708, DK02, DK05, FI19, FI1D, FRB, FRC, FRD, FRF, FRM, DE8, DEE, PT2, SE3
# Adding interactivity to chart R2F16: Map
# Adding interactivity to chart R2F17: Dumbbells
# Data for the following regions not found: AT2, BE2, HR02, CZ0708, DK02, DK05, FI19, FI1D, FRB, FRC, FRD, FRF, FRM, DE8, DEE, NL1, PT2, SE3
# Adding interactivity to chart R2F18: Map
# Adding interactivity to chart R2F19: Map
# Tooltips for the following regions not found: IE06, IE04, IE05
# Polygons for the following regions not found:
# No SVG handler method for R2F20 - type: Table. Saving SVG object to target
# Adding interactivity to chart R2F21: Map
# Adding interactivity to chart R2F22: Map
# Adding interactivity to chart R2F23: Map
# Tooltips for the following regions not found: IE06, IE04, IE05
# Polygons for the following regions not found:
# Adding interactivity to chart R2F24: Map
# Tooltips for the following regions not found: IE06, IE04, IE05
# Polygons for the following regions not found:
# Adding interactivity to chart R2F25: Bars
# Data for the following countries not found: IE
# Adding interactivity to chart R2F26: Bars
# Data for the following countries not found: IE
# Adding interactivity to chart R2F27: Bars
# Data for the following countries not found: IE
# Adding interactivity to chart R2F28: Bars
# Data for the following countries not found: IE
# Adding interactivity to chart R2F29: Bars
# Data for the following countries not found: IE
# Adding interactivity to chart R2F30: Dumbbells
# Data for the following regions not found: DK02, DK03, DK05, FI19, FRB, FRD, FRH, FRM, DE8, DEC, NL1, NL2, PT2, SI03
# Adding interactivity to chart R2F31: Scatterplot
# Adding interactivity to chart R2F32: Map
# Adding interactivity to chart R2F33: Map
# Adding interactivity to chart R2F34: Dumbbells
# Data for the following regions not found: DK01, DK02, DK03, DK05, FI19, FRB, FRD, FRH, FRM, DE8, DEC, NL1, NL2, PT2, SI03
# Adding interactivity to chart R2F35: Scatterplot
# Adding interactivity to chart R2F36: Map
# Adding interactivity to chart R2F37: Map
# Adding interactivity to chart R2F38: Dumbbells
# Data for the following regions not found: DK02, DK03, DK05, FI19, FRB, FRD, FRH, FRM, DE8, DEC, NL1, NL2, PT2, SI03
# Adding interactivity to chart R2F39: Scatterplot
# Adding interactivity to chart R2F40: Map
# Adding interactivity to chart R2F41: Dumbbells
# Data for the following regions not found: AT2, DK02, DK03, DK04, DK05, FI19, FRB, FRC, FRD, FRG, FRH, FRM, DE5, DE8, DEC, MT00, NL1, NL2, PT2, SI03, SE3
# Adding interactivity to chart R2F42: Dumbbells
# Data for the following regions not found: DK01, DK02, DK03, DK04, DK05, FI19, FRB, FRD, FRH, FRM, DE8, DEC, DED, MT00, NL1, NL2, PT2, SI03
# Adding interactivity to chart R2F43: Map
# Adding interactivity to chart R2F44: Map
# Adding interactivity to chart R2F45: Map
# Adding interactivity to chart R2F46: Map
# Adding interactivity to chart R2F47: Dumbbells
# Data for the following regions not found: HR02, HR06, DK02, DK03, DK05, FI19, FRB, FRC, FRD, FRF, FRH, FRM, DE8, DEC, DEE, NL1, NL2, PT2, SI03
# Adding interactivity to chart R2F48: Scatterplot
# Adding interactivity to chart R2F49: Map
# Adding interactivity to chart R2F50: Map
# Adding interactivity to chart R2F51: Map
# Adding interactivity to chart R2F52: Map
# Adding interactivity to chart R2F53: Map
# Adding interactivity to chart R2F54: Dumbbells
# Data for the following regions not found: AT2, CZ0708, DK02, DK03, DK05, FI19, FRB, FRD, FRH, FRM, DE5, DE8, DEC, DEE, MT00, NL1, NL2, PT2, SI03
# Adding interactivity to chart R2F55: Map
# Adding interactivity to chart R2F56: Map
# Adding interactivity to chart R2F57: Map
# Adding interactivity to chart R3F1: Dumbbells
# Data for the following regions not found: AT2, BE3, HR02, HR06, CZ0708, DK02, DK05, FI19, FI1C20, FI1D, FRB, FRC, FRD, FRF, FRG, FRH, FRM, DE8, DEE, IE04, PL7, PT2, SE3
# Adding interactivity to chart R3F2: Lollipop
# Data for the following regions not found: CY0, EE0, LV00, LU00, MT00
# Adding interactivity to chart R3F3: Lollipop
# Data for the following regions not found: CY0, EE0, LV00, LU00, MT00
# Adding interactivity to chart R3F4: Lollipop
# Data for the following regions not found: CY0, EE0, LV00, LU00, MT00
# Adding interactivity to chart R3F5: Lollipop
# Data for the following regions not found: CY0, EE0, LV00, LU00, MT00
# Adding interactivity to chart R3F6: Lollipop
# Data for the following regions not found: CY0, EE0, LV00, LU00, MT00
# Adding interactivity to chart R3F7: Lollipop
# Data for the following regions not found: CY0, EE0, LV00, LU00, MT00
# Adding interactivity to chart R3F8: Lollipop
# Data for the following regions not found: CY0, EE0, LV00, LU00, MT00
# Adding interactivity to chart R3F9: Lollipop
# Data for the following regions not found: CY0, EE0, LV00, LU00, MT00
# Adding interactivity to chart R3F10: Lollipop
# Data for the following regions not found: CY0, EE0, LV00, LU00, MT00
# Adding interactivity to chart R3F11: Lollipop
# Data for the following regions not found: CY0, EE0, LV00, LU00, MT00
# Adding interactivity to chart R3F12: Lollipop
# Data for the following regions not found: CY0, EE0, LV00, LU00, MT00
# Adding interactivity to chart R3F15: Lollipop
# Data for the following regions not found: CY0, EE0, LV00, LU00, MT00
# Adding interactivity to chart R3F16: Map
# Adding interactivity to chart R3F17: Map
# Adding interactivity to chart R3F18: Map
# Adding interactivity to chart R3F19: QRQ Bars
# Adding interactivity to chart R3F20: Lollipop
# Data for the following regions not found: CY0, EE0, LV00, LU00, MT00
# Adding interactivity to chart R3F21: Dumbbells
# Data for the following regions not found: BE3, HR02, DK02, DK05, FRB, FRC, FRD, FRF, FRG, FRH, FRM, DEE, PL7, PT2, SE3
# Adding interactivity to chart R3F22: Dumbbells
# Data for the following regions not found: BE3, HR02, DK02, DK05, FRB, FRC, FRD, FRF, FRG, FRH, FRM, DEE, PL7, PT2, SE3
# Adding interactivity to chart R3F23: Dumbbells
# Data for the following regions not found: BE3, HR02, DK02, DK05, FRB, FRC, FRD, FRF, FRG, FRH, FRM, DEC, DEE, PL7, PT2, SE3
# Adding interactivity to chart R3F24: Map
# Adding interactivity to chart R3F25: Map
# Adding interactivity to chart R3F26: Dumbbells
# Data for the following regions not found: BE3, HR02, DK02, DK05, FRB, FRC, FRD, FRF, FRM, DEE, IE04, PT2, SE3
# Adding interactivity to chart R3F27: Map
# Adding interactivity to chart R3F28: Map
# Adding interactivity to chart R3F29: Map
# Adding interactivity to chart R3F30: Map
# Adding interactivity to chart R3F31: Dots
# Data for the following regions not found: SE
# Adding interactivity to chart R3F32: Dumbbells
# Data for the following regions not found: AT2, BE3, HR02, HR06, CZ0708, DK02, DK05, FI19, FI1C20, FI1D, FRB, FRC, FRD, FRE, FRF, FRG, FRM, DE4, DE8, DEE, IE04, PT2, SE3
# Adding interactivity to chart R3F33: Dumbbells
# Data for the following regions not found: BE3, HR02, HR06, DK02, DK03, DK04, DK05, FI19, FI1C20, FRB, FRC, FRD, FRE, FRF, FRH, FRM, DEE, IE04, NL4, PT2, SE3
# Adding interactivity to chart R3F34: Dumbbells
# Data for the following regions not found: BE3, HR02, HR06, DK02, DK05, FI19, FI1C20, FRB, FRC, FRD, FRE, FRF, FRM, DEE, IE04, PT2, SE3

# %% [markdown]
# ## Testing Ground

# %%
# original = SVGhandler.svg("R2F31", "Scatterplot")
# original.addInteractivity(color_scheme["Scatterplot"])
